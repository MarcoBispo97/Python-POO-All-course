# %% [markdown]
# # Introduction to Instances:
# - An object created from the class
# - Class is similar an abstract representation of an object
# - `Instance Attributes:`
#     - They are variables that belong to a particular object.
# - Instances attribute are `idependents` and `differents`
# - They belong to the object
# - Attributes can have unique values for each instances
# - Multiple attributes are different:
#
# - For example:
#     - Backpack:
#         - Size
#         - Color
#         - Weight
#         - Material
#         - Number of pockets
#         - Number of zippers
#     - Video Game:
#         - Sprite
#         - Score
#         - Number of lives
#         - Speed
#         - X-coordinate
#         - Y-coordinate

# %% [markdown]
# # Instance Attributes: __init__()
# - `__init__()`:
#     - Special method used to define the initial state of an object.
#     - Called automatically when an instance is created
# ``` python
#
# class House:
#     # __init__: The constructor. Called automatically when a new object is created.
#     # recive the input attributes
#     # Its purpose is to initialize the object's state.
#     def __init__(self, price):
#
#         # self: A reference to the current instance of the class (the object itself).
#         # Used to access or set attributes on the object.
#
#         # self.price: An "instance attribute".
#         # This attaches the 'price' to the specific object ('self').
#         self.price = price
#
# # --- Example ---
# # house_a = House(500000)
# # 1. A new House object is created.
# # 2. __init__ is called on this new object.
# # 3. The object is passed as 'self'; 500000 is passed as 'price'.
# # 4. 'self.price = 500000' creates the price attribute on house_a.
# ```

# %% [markdown]
# ``` python
# class Carro:
#     # Aqui, marca, modelo e ano são parâmetros de entrada
#     def __init__(self, marca, modelo, ano):
#         # Aqui, esses valores agora se tornam atributos da instância
#         self.marca = marca
#         self.modelo = modelo
#         self.ano = ano
#
#
#     def exibir_informacoes(self):
#         print(f"Carro: {self.marca} {self.modelo}, Ano: {self.ano}")
#
# # Nesse exemplo, quando criamos um novo objeto Carro, por exemplo:
# meu_carro = Carro("Toyota", "Corolla", 2020)
#
# ```

# %% [markdown]
# # Best practices ``__init__()`:
# ``` python
# # Not recommneded
# def __init__(self,name,age, hairColor):
# # Recommended
# def __init__(self, name, age, hair_color):
# ```

# %% [markdown]
# # Instances and `self` OOP:
# - Classes define the state and the gehavior of the objects in a `generic` way
# - It is not specific. The code in the class has to work for `any` instance of the class
# - `self` is a generic way of refering to the current instance of the class
# ``` python
# class House:
#     def __init__(self, price):
#         # 1 Assign the value of the variable price
#         # 2 To the instance attribute "price"
#         # 3 Of the instance that is being created
#         # price is the parameter of the init method
#         # self.price is the attribute of the instance
#         # These elements are not equal
#         self.price = price
# ```
# ``` python
# class Backpack:
#     def __init__(self, color, size):
#         self.items = []
#         self.color = color
#         self.size = size
# ```

# %% [markdown]
# # Define instances attributes:
# ``` python
# class Circle:
#     def __init__(self, radius, pi = 3.1415):
#         self.area = area
#         self.pi = pi
#
# class Square:
#     def __init__(self, length, color = 'Blue'):
#         self.length = length
#         self.color = color
#
# class Movie:
#     def __init__(self, title, year, language, rating):
#         self.title = titwe
#         self.year = year
#         self.language = language
#         self.rating = rating
# ```

# %% [markdown]
# # How to create Instances in Python:
# -  `self` is "skipped" in the arguments list when create an instance
#     - No arguments:
#         <ClassName>()
#         ``` python
#         class Backpack:
#             def __init__(self):
#                 self.items = []
#
#         my_backpack = Backpack()
#         print(my_backpack)
#         # Return
#         # <__main__.Backpack object at 0x0000029A2DD11010>
#         # memory location
#         ```
#     - Whith arguments:
#         <ClassName>(<value>)
#         ```` python
#         class Circle:
#             def __init__(self, radius):
#                 self.radius = radius
#         radius = 3
#         my_circle = Circle(radius)
#         print(my_circle)
#         # Return
#         # <__main__.Backpack object at 0x0000029A2DD11010>
#         # memory location
#         ````
#     - Multiple arguments:
#         <ClassName>(<arguments>)
#         ``` python
#         class Rectangle:
#             def __init__(self, length, width):
#                 self.length = length
#                 self.width = width
#
#         my_rectangle = Rectangle(3, 6) # 2 arguments here !
#         # Return
#         # <__main__.Rectangle object at 0x0000029A2DD11550>
#         # memory location
#         ```

# %%
class Rectangle:
    def __init__(self, length, width):
        self.length = length
        self.width = width

my_rectangle = Rectangle(3, 6)
print(my_rectangle)

# %%
        class Circle:
            def __init__(self, radius):
                self.radius = radius
        radius = 3
        my_circle = Circle(radius)
        print(my_circle)

# %%
class Backpack:
    def __init__(self):
        self.items = []

my_backpack = Backpack()
print(my_backpack)

# %% [markdown]
# # Questions
# - What is an instance in object-oriented programming ?
#     - A specific object created from a class
# - Are the instances of a class independent of each other ?
#     - Yes, they independent. Their attributes can have different values
# - How do you write the first line of an `__init__` method that takes a `name` parameter ?
#     - ``` python
#         def __init__(self, name):
#     ```
# - Given this __init__ method, what attributes will the instances of this class have?
# ``` python
# def __init__(self, radius, angle):
#     self.radius = radius
#     self.angle = angle
#     self.color = "blue"
# ```
#     - `radius, angle, color`
# - Which code snippet correctly initializes the `magnitude, latitude, longitude`, and `scale` attributes in the ___init__ method ?
#     ```python
#     def __init__(self, magnitude, latitude, longitude, scale):
#         self.magnitude = magnitude
#         self.latitude = latitude
#         self.longitude = longitude
#         self.scale = scale
#     ```
# - Which one of these options creates an instance of the Player class and assigns it to a variable named my_player? (You may assume that no arguments are required).
#     ```python
#     my_player = Player()
#     ```
# - What error message will you see if you try to run this code?
#     ``` python
#     class Color:
#
#         def __init__(self, red, green, blue):
#             self.red = red
#             self.green = green
#             self.blue = blue
#
#     favorite_color = Color(67, 32)
#     ```
#     - TypeError: Color.__init__() missing 1 required positional argument: `blue`

# %%
def is_none_corrigido(value):
    # if value is None:
    #     print(True)
    # else:
    #     print(False)
    print(value is None)
# Testando a função corrigida
preference = []
is_none_corrigido(preference)  # Imprime False, pois [] não é None

valor_nulo = None
is_none_corrigido(valor_nulo)  # Imprime True, pois o valor é None

# %% [markdown]
# # How to access Intance
# - `<object>.<attribute>`
# - Dot Notation:
#     - Syntax used to access the members of an object (its variables and methods)
#     - self.<attribute>
#     ``` python
#     class Backpack:
#         def __init__(self):
#             self.items = []
#             print(self.items)
#
#         my_backpack = Backpack()
#         # Return
#         #   []
#     ```
#     - But outside of the class we need to `object.<attribute>`
#     ``` python
#     class Backpack:
#         def __init__(self):
#             self.items = ["Water Bottle", "Pencils"]
#
#     my_backpack = Backpack()
#     print(my_backpack)
#     #Return
#     #   ["Water Bottle", "Pencils"]
#     ```

# %% [markdown]
# # Access instance Attributes
# ``` python
#     class Movie:
#         def __init__(self, title, year, language, rating):
#             self.title = title
#             self.year = year
#             seçlf.language = language
#             self.rating = rating
#     favorite_movie = Movie(
#         "Pride and Prejudice",
#         2005,
#         "English",
#         4.8
#     )
#     print(favorite_move.title)
#     print(favorite_movie.year)
#     print(favorite_movie.language)
#     print(favorite_movie.rating)
# ```

# %%
class Movie:
    def __init__(self, title, year, language, rating):
        self.title = title
        self.year = year
        self.language = language
        self.rating = rating
my_favorite_movie = Movie(
    "Pride and Prejudice",
    2005,
    "English",
    4.8
)
your_favorite_movie = Movie(
    "Titanic",
    1997,
    "English",
    4.6,
)
print("My favorite Movie:")
print(my_favorite_movie.title)
print(my_favorite_movie.year)
print(my_favorite_movie.language)
print(my_favorite_movie.rating)
print("\n")
print("Your Favorite Movie")
print(your_favorite_movie.title)
print(your_favorite_movie.year)
print(your_favorite_movie.language)
print(your_favorite_movie.rating)

# %% [markdown]
# # Default Arguments
# - Default values assigned to parameters when their correspomnding arguments are omitted
# -`<parameter>=<value>`
# - Correct:
#     ```python
#     def complex(real, imag=0.0):
#         return magic(r=real, i-imag)
#     ```
# - Wrong:
#     ``` python
#     def complex(real, imag = 0.0):
#         return magic(r = real, i = imag)
#     ```
# - Example:
#     ```python
#     class Circle:
#         def __init__(self, radius=5):
#             self.radius = radius
#     my_circle = Circle()
#     print(my_circle.radius)
#     # Return 5
#     my_circle = Circle(10)
#     print(my_circle.radius)
#     ```

# %%
class Circle:
    def __init__(self, radius=5):
        self.radius = radius
        self.color = "Blue"
my_circle = Circle()
print(my_circle.radius)
# Return 5
my_circle = Circle(10)
print(my_circle.radius)
print(my_circle.color)
# Out:
# 5
# 10
# Blue

# %% [markdown]
# # For Loops and Instances:
# - Here we have a `Player` class with instance attrbues `x` and `y`, the coordinates of the player in a 2D world:
# ``` python
# class Player:
#     def __init__(self, x, y):
#         self.x = x
#         self.y = y
#
# player1 = Player(5, 6)
# player2 = Player(2, 4)
# player3 = Player(3, 6)
#
# players = [
#     player1,
#     player2,
#     player3
# ]
#
# for player in players:
#     print(f"X: {`palyer.x} Y: {player.y}")
# ```
#
# - Syntax:
#     ``` python
#     for instance in sequence:
#     ```

# %% [markdown]
# # Modify the Value of Instance Attributes
# - <object>.<attribute> = <new_value>
# - self.<attribute> = <new_value>
# ``` python
# class Backpack:
#     def __init__(self, color):
#         self.items = []
#         self.color = color
# my_backpack = Backpack("Blue")
# print(my_backpack.color)
# # Return: Blue
# my_backpack.color = "Green"
# print(my_backpack.color)
# # Return: Green
# ```

# %% [markdown]
# # Exemple Modify/ Update Instance Attributes
# ``` python
# class Circle:
#     def __init__(self, radius=5, color):
#         self.radius = radius
#         self.color = color
# my_circle = Circle(6, color="Red")
# print(my_circle.radius)
# # Return 6
# print(my_circle.color)
# # Return Red
# my_circle.color = "Green"
# print(my_circle.color)
# # Return Green
# my_circle.radius = 10
# print(my_circle.radius)
# # Return 10
# ```

# %% [markdown]
# # `Del` Delete Instance Attributes with `del`
# - del instance.attribute
# - Example:
#     ``` python
#     class Dog:
#         def __init__(self, name):
#             self.name = name
#     dog = Dog("Nora")
#     print(dog.name)
#     # Return Nora
#     ```
#     - Let's delete it:
#         ``` python
#         del dog.name
#         ```

# %% [markdown]
# # `Del` Delete Instance Attributes with `del`
# - del instance.attribute
# - delattr(instance, attribute)

# %%
class Dog:
    def __init__(self, name):
        self.name = name
dog = Dog("Nora")
print(dog.name)
# Return Nora
del dog.name
print(dog.name)
# Return AttributeError: 'Dog' object has no attribute 'name'
# Out:
# Nora
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 8
#       6 # Return Nora
#       7 del dog.name
# ----> 8 print(dog.name)
#       9 # Return AttributeError: 'Dog' object has no attribute 'name'
#
# AttributeError: 'Dog' object has no attribute 'name'

# %%
# Delete Instance Attributes with delattr
class Dog:
    def __init__(self, name):
        self.name = name
        
dog = Dog("Nora")
print(dog.name)
# Return Nora
delattr(dog, "name")
print(dog.name)
# Return AttributeError: 'Dog' object has no attribute 'name'
# Out:
# Nora
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 10
#       8 # Return Nora
#       9 delattr(dog, "name")
# ---> 10 print(dog.name)
#      11 # Return AttributeError: 'Dog' object has no attribute 'name'
#
# AttributeError: 'Dog' object has no attribute 'name'

# %% [markdown]
# # Questions:
# - 1 What are instance attributes in Python?
#     - Variables that belong to specific instances of a class
# - 2 Can you modify the value of an instance attribute after the object is created?
#     - Yes, you can modify them using dot notation.
# - 3 How can you access the phone_number attribute of an instance of the Restaurant class called gourmet_world?
#     - `gourmet_world.phone_number`
# - 4 What error message will you see if you try to run this code?
#     ``` python
#     class Donut:
#
#     def __init__(self, size, calories, flavor):
#         self.size = size
#         self.calories = calories
#         self.flavor = flavor
#
#     my_donut = Donut("Medium", 125, "Chocolate")
#
#     print(my_donut.price)
#     ```
#     - `AttributeError: 'Donut' object has no attribute 'price'`
# - 5 What is hte purpose of default arguments in an ´__init__´ method ?
#     - To provide default values for optional parameters
# - 6 What willl be the output of this program ?
#     ``` python
#     class Ticket:
#         def __init__(self, price=1.25):
#             self.price = price
#
#     my_ticket = Ticket()
#     print(f"my_ticket: {my_ticket.price}")
#     #Return 1.25
#     ```
#
# - 7 What build-in Python deletes a specified instance attribute dynamically from the specified object ?
#     - `delattr()`

# %% [markdown]
# # Task:
# - Now it's time to apply your knowledge in this practice project. You will use a class to represent bacteria in educational software for a small school district. Are you ready? Let's begin!
#
# ## For this assignment, you will define a Bacterium class to represent the enemies in the game.
#
# - The class must have:
#
# - Five custom instance attributes. You may need to research online to determine these instance attributes based on the characteristics of bacteria (you can find helpful resources below).
#
# - The instance attributes x and y to represent the coordinates of the instance on the computer screen. Their values must be passed as arguments to __init__() and assigned as instance attributes.
#
# - After defining the class:
#
# - Create three instances. You can customize the arguments that will be used to create them.
#
# Tips:
#
# - To help you choose the instance attributes, think about the most useful attributes for an enemy in a microbiology game.
# - For example, you could add a life_counter attribute as a generic attribute that is not specific to bacteria. This can be helpful for the game.
# - You could also add attributes that are specific to bacteria, such as their classification or shape.
# - You are in complete control of this assignment, so you can customize it to your liking. There is a Python file included with this assignment (below) that you can download to start writing your class.

# %%
class Bacterium:
    def __init__(self, name, shape, gram_type, reproduction_rate, life_counter, x, y):
        # Bacteria-specific attributes
        self.name = name
        self.shape = shape
        self.gram_type = gram_type
        self.reproduction_rate = reproduction_rate  # divisions per minute (example)

        # Game-related attributes
        self.life_counter = life_counter

        # Screen position
        self.x = x
        self.y = y

    def take_damage(self, damage):
        self.life_counter -= damage
        if self.life_counter < 0:
            self.life_counter = 0

    def is_alive(self):
        return self.life_counter > 0

bacteria_1 = Bacterium(
    name="Escherichia coli",
    shape="bacillus",
    gram_type="Gram-negative",
    reproduction_rate=20,
    life_counter=100,
    x=50,
    y=120
)

bacteria_2 = Bacterium(
    name="Staphylococcus aureus",
    shape="cocci",
    gram_type="Gram-positive",
    reproduction_rate=30,
    life_counter=120,
    x=200,
    y=80
)

bacteria_3 = Bacterium(
    name="Spirillum volutans",
    shape="spirillum",
    gram_type="Gram-negative",
    reproduction_rate=15,
    life_counter=90,
    x=350,
    y=200
)

# %% [markdown]
# # Questions:
# - 1 What is the primary purpose of instances in object-oriented programming?
#     - To create specific objects with their own data and behavior
# - 2 When is the `__init__()` method of a class automatically called ?
#     - When an instance of the class is created
# - 3 What is the purpose of the self parameter in an __init__ method ?
#     - To refer to the current instance of the class
# - 4 What is the error in the following __init__ method definition?
#     ``` python
#     def __init__(mass, volume):
#         self.mass = mass
#         self.volume = volume
#     ```
#     - self should be the first parameter
# - 5 Consider the following class:
#     ``` python
#     class Car:
#
#         def __init__(self, color, model):
#             self.color = color
#             self.model = model
#     ```
#     - How would you create an instance of this class named my_car with the color "purple" and the model "Sedan"?
#     ``` python
#     my_car = Car("purple","Sedan")
#     ```
# - 6 How do you access the name attribute of a Dog instance named nora ?
#     `nora.name`
# - 7 Consider the following class:
#     ``` python
#     class Customer:
#
#         def __init__(self, name, age=53):
#             self.name = name
#             self.age = age
#     ```
#     - What will be the age of the customer object created using the following code?
#     ``` python
#     gino = Customer("Gino")
#     ```
#     - 53
