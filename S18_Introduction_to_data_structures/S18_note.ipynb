# %% [markdown]
# # What is a Data Structure ?

# %% [markdown]
# # Data Structure:
# - Any of various methods or formats (such as an array, file, or recod) for organizing data in a computer.
# - Organize the data efficiently and optimize common operations (read, add, remove, and update).
# - Elements are connected
# - Consider pros and cons of each data structure based on the problem
# - Why OOP is important to data structure ?
#     - OOP is their "backbone"
#         - Elements
#         - Data
#         - Connections
#         - Operations
# - Arrays + List
# - Trees
# - Graphs
# - Linked List

# %% [markdown]
# - Nodes in Data Structures:
#     - A basic unit of a data structure
#     - 2 main elements
#         - Data
#         - Connections
#     - Pointer:
#         - A reference to another node in the data structure
