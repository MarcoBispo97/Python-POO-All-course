# %% [markdown]
# # Classes:
# - Is a **blueprint** in your code to create objects
# - In your class we define a **state** and **behavior**
# - Classes are factories of objects (use the blueprint to create as many obj we needed)
# - You can defign the class
# - Naming Convetion class
#     - In Python we use **PascalCase**:
#         - `House`
#         - `FactoryBackpack`
#         - `SchoolBackpack`
# - Class Header:
#     - First Line of a class definition. It specifies the name of the class and if it inherits from another class.
#         ```python
#         class ClassName:
#         ```

# %% [markdown]
# # How to identify Classes:
# - 1 Class FastFood:
#     - Our store serves dast food. The items sold include **pizza, burgers, and hot dogs**. We also sell **soda, water, and French fries**. Clients may choose to buy one or more items.
#         If They choose to buy more than one item, they receive a **special discount of 20%**. The store has **five employess**.
# ```python
# classes = [
#     foods = [pizza, burgers, hot dogs, French fries]
#     drinks = [soda, water]
#     people = {
#         clients: number_clients,
#         employees: list(range(6)),
#     }
# ]
# special_discount = 0.2
# ```
# - Questions:
#     - Is this term needed for the scope of the project ?
#     - Does the term represent an example of a class What class ?
#     - Is this class important for the program that we are creating ?
#
# - 2 Class EletronicStore:
#     - Our electronic store sells laptops, desktops, tablets, smartphones, notebooks, pen drives, and heaphones.
#     We also sell accessories for theses devices. The store has 10 employees and one manager. Clients are registered whe they make their first purchase.
# ```python
# classes = {
#     devices : [laptops, desktops, tablets, smartphones, notebooks, pen drives, heaphones],
#     acessories : [something],
#     people : {
#         employees : list(range(11)),
#         managers : list(range(1)),
#     }
# }
# ```
#
# - 3 Class MazeGame:
#     - Our maze game will have five levels. The player will move to each level once it reaches the goal. There are two types of enemies:
#     ants and toads. If the player collides with either one of them, the level starts again until the player has no more lives left.
# ``` python
# classes = [
#     levels : 5,
#     palyers : 1,
#     enemies : [ants, toads]
#     Colide : [True, False]
# ]
# ```

# %% [markdown]
# # Classes in Python: Initial Syntax:
# ``` python
# class BACKPACK
#     pass
# ```
# - Header:
#     - `First line` of a class definition. It specifies the name of the class and if it inherits from another class
#     ```python
#     #keyword
#     class
#     #Name
#     <ClassName>:
#     ```
# - Body:
#     - Contains the elements of the `blueprint`, including the attributes and beahvior of the objects.
#
# - Elements:
#     - `Class Attributes`
#     - `__init__()`
#     - `Methods`
#
# - Example:
#     ```python
#     class ClassName:
#     # Class Attribute
#     # __init__()
#     # Methods
#     ```

# %% [markdown]
# # Problem Statement
# -   Our shelter takes care of `dogs, cats, parrots, lizards`, and `snakes`.
#     Six employees work for the `shelter` and `volunteers` help the staff.
#     The shelter regulary receives `donatiomns` and the `donors` are registered in the system.
#     ``` python
#     classes = {
#         animals : [
#             'dogs',
#             'cats',
#             'parrots',
#             'lizards',
#             'snakes'
#         ],
#         people : [
#             'Employees',
#             'Volunteers',
#             'Donors'
#         ]}
#     ```

# %% [markdown]
# # Class Sintax:
#
# ``` python
# # Header
# Class Example:
#     #Body
#     def __init__(self, foo, bla):
#         self.bla = bla #atribute bla
#         self.foo = foo # atribute foo
#     # Methods
#     def do_something(bla):
#         pass
# # Pay attention in identend elements
# ```

# %% [markdown]
# # Questions:
# - 1 What is a class in OOP ?
#     - It is a blueprint for creating objects.
# - 2 What are the key components of a class ?
#     - Attribues and methods
# - 3 Is this Python class header declared correctly ``def Cat:`?
#     No, it's not correct
# - 4 Is this Python class header declared correctly ``class Tree:`?
#     Yes, this is correct
# - 5 What's the correct syntax for the class header of a `Videogame class`?
#     `class Videogame:`
# - 6 What is the first step in identify potential classes in a problem description ?
#     Identify the nouns
# - 7 Wich one of these options follows the correct naming convention for classes in Python ?
#     `LinkedList (PascalCase)`

# %% [markdown]
# # Real-World Applications of Classes (Mini Project)
# - In this assignment, you'll design and implement a solution to a specific problem. Please follow the instructions carefully and submit your solution. You are welcome to check out the sample solution for guidance.
#
# Identify 3 classes that might be needed for a program developed for a:
#
# Bank
#
# Donut Shop
#
# Videogame Store
#
# Think about the objects that a program might need in these scenarios.
#
# For example, a pizza store could represent a Pizza with a class and an Employee with another class.
#
#
#
# Format:
#
# Please write your answers in this format:  <context> : <class>, <class>, <class>
#
# For example: Pizza Store: Pizza, Employee, Topping
#
# - `Small Bank: SavingsAccount, CheckingAccount, CreditCard.`
#
# - `Donut Shop: Donut, Soda, Topping.`
#
# - `Videogame Store: Videogame, Client, Employee.`
